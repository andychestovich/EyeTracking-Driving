# %%
# loading the results for random forest and xgboost
results1_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results1.csv")
results2_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results2.csv")
results3_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results3.csv")
results4_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results4.csv")
results5_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results5.csv")
results6_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results6.csv")
results7_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results7.csv")
results8_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results8.csv")
results9_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results9.csv")
results10_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/rf_results10.csv")


results1_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results1.csv")
results2_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results2.csv")
results3_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results3.csv")
results4_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results4.csv")
results5_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results5.csv")
results6_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results6.csv")
results7_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results7.csv")
results8_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results8.csv")
results9_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results9.csv")
results10_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_15s/xgb_results10.csv")

results1_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle1.csv")
results2_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle2.csv")
results3_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle3.csv")
results4_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle4.csv")
results5_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle5.csv")
results6_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle6.csv")
results7_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle7.csv")
results8_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle8.csv")
results9_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle9.csv")
results10_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_15s/rocketresults_vehicle10.csv")

# %%
results_list_rf = [results1_rf, results2_rf, results3_rf, results4_rf, results5_rf,
                results6_rf, results7_rf, results8_rf, results9_rf, results10_rf]
for idx, i in enumerate(results_list_rf):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1  # or use idx if you want 0-based

results_list_xgb = [results1_xgb, results2_xgb, results3_xgb, results4_xgb, results5_xgb,
                               results6_xgb, results7_xgb, results8_xgb, results9_xgb, results10_xgb]
for idx, i in enumerate(results_list_xgb):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

results_list_rocket = [results1_rocket, results2_rocket, results3_rocket, results4_rocket, results5_rocket,
                               results6_rocket, results7_rocket, results8_rocket, results9_rocket, results10_rocket]
for idx, i in enumerate(results_list_rocket):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

max_tpr_rf_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rf]
max_tpr_xgb_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_xgb]
max_tpr_rocket_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rocket]

rf_multiples = 10*['Random Forest']
rocket_multiples = 10*['ROCKET']
xgb_multiples = 10*['XGBoost']
multiples_15s = 10*['15']
tpr_df_rf_15s = pd.DataFrame({
    'time': multiples_15s,
    'model': rf_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rf_by_split
})
tpr_df_xgb_15s = pd.DataFrame({
    'time': multiples_15s,
    'model': rocket_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_xgb_by_split
})
tpr_df_rocket_15s = pd.DataFrame({
    'time': multiples_15s,
    'model': xgb_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rocket_by_split
})

# %%
results_list_rf
# Out:
# [     sample_ID  predicted_prob  target  pred  max_tpr_split  split
#  0     13_10_3A        0.904897       1     1       0.183046      1
#  1     13_11_3A        0.982350       1     1       0.183046      1
#  2     13_12_3A        0.996573       1     1       0.183046      1
#  3     13_13_3A        0.998066       1     1       0.183046      1
#  4     13_14_3A        0.975789       1     1       0.183046      1
#  ...        ...             ...     ...   ...            ...    ...
#  4076   24_7_3B        0.180276       0     0       0.183046      1
#  4077  24_80_3B        0.483478       0     0       0.183046      1
#  4078  24_81_3B        0.467886       0     0       0.183046      1
#  4079   24_8_3B        0.359299       0     0       0.183046      1
#  4080   24_9_3B        0.178584       0     0       0.183046      1
#
#  [4081 rows x 6 columns],
#         sample_ID  predicted_prob  target  pred  max_tpr_split  split
# ...

# %%
max_tpr_rf_by_split
# Out:
# [0.18304552590266876,
#  0.11239935587761675,
#  0.12587859424920128,
#  0.0,
#  0.11461844927980386,
#  0.0,
#  0.14050091631032377,
#  0.08318840579710145,
#  0.09148629148629149,
#  0.1363773813123677]

# %%
tpr_df_all_15s = pd.concat([tpr_df_rf_15s, tpr_df_xgb_15s, tpr_df_rocket_15s], ignore_index=True)

# %%
# loading the results for random forest and xgboost
results1_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results1.csv")
results2_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results2.csv")
results3_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results3.csv")
results4_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results4.csv")
results5_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results5.csv")
results6_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results6.csv")
results7_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results7.csv")
results8_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results8.csv")
results9_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results9.csv")
results10_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/rf_results10.csv")


results1_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results1.csv")
results2_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results2.csv")
results3_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results3.csv")
results4_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results4.csv")
results5_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results5.csv")
results6_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results6.csv")
results7_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results7.csv")
results8_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results8.csv")
results9_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results9.csv")
results10_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_30s/xgb_results10.csv")

results1_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle1.csv")
results2_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle2.csv")
results3_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle3.csv")
results4_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle4.csv")
results5_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle5.csv")
results6_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle6.csv")
results7_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle7.csv")
results8_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle8.csv")
results9_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle9.csv")
results10_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_30s/rocketresults_vehicle10.csv")

# %%
results_list_rf = [results1_rf, results2_rf, results3_rf, results4_rf, results5_rf,
                results6_rf, results7_rf, results8_rf, results9_rf, results10_rf]
for idx, i in enumerate(results_list_rf):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1  # or use idx if you want 0-based

results_list_xgb = [results1_xgb, results2_xgb, results3_xgb, results4_xgb, results5_xgb,
                               results6_xgb, results7_xgb, results8_xgb, results9_xgb, results10_xgb]
for idx, i in enumerate(results_list_xgb):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

results_list_rocket = [results1_rocket, results2_rocket, results3_rocket, results4_rocket, results5_rocket,
                               results6_rocket, results7_rocket, results8_rocket, results9_rocket, results10_rocket]
for idx, i in enumerate(results_list_rocket):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

max_tpr_rf_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rf]
max_tpr_xgb_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_xgb]
max_tpr_rocket_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rocket]


multiples_30s = 10*['30']
tpr_df_rf_30s = pd.DataFrame({
    'time': multiples_30s,
    'model': rf_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rf_by_split
})
tpr_df_xgb_30s = pd.DataFrame({
    'time': multiples_30s,
    'model': rocket_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_xgb_by_split
})
tpr_df_rocket_30s = pd.DataFrame({
    'time': multiples_30s,
    'model': xgb_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rocket_by_split
})
tpr_df_all_30s = pd.concat([tpr_df_rf_30s, tpr_df_xgb_30s, tpr_df_rocket_30s], ignore_index=True)

# %%
# loading the results for random forest and xgboost
results1_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results1.csv")
results2_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results2.csv")
results3_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results3.csv")
results4_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results4.csv")
results5_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results5.csv")
results6_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results6.csv")
results7_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results7.csv")
results8_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results8.csv")
results9_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results9.csv")
results10_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/rf_results10.csv")


results1_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results1.csv")
results2_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results2.csv")
results3_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results3.csv")
results4_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results4.csv")
results5_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results5.csv")
results6_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results6.csv")
results7_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results7.csv")
results8_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results8.csv")
results9_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results9.csv")
results10_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_45s/xgb_results10.csv")

results1_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle1.csv")
results2_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle2.csv")
results3_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle3.csv")
results4_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle4.csv")
results5_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle5.csv")
results6_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle6.csv")
results7_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle7.csv")
results8_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle8.csv")
results9_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle9.csv")
results10_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_45s/rocketresults_vehicle10.csv")

# %%
results_list_rf = [results1_rf, results2_rf, results3_rf, results4_rf, results5_rf,
                results6_rf, results7_rf, results8_rf, results9_rf, results10_rf]
for idx, i in enumerate(results_list_rf):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1  # or use idx if you want 0-based

results_list_xgb = [results1_xgb, results2_xgb, results3_xgb, results4_xgb, results5_xgb,
                               results6_xgb, results7_xgb, results8_xgb, results9_xgb, results10_xgb]
for idx, i in enumerate(results_list_xgb):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

results_list_rocket = [results1_rocket, results2_rocket, results3_rocket, results4_rocket, results5_rocket,
                               results6_rocket, results7_rocket, results8_rocket, results9_rocket, results10_rocket]
for idx, i in enumerate(results_list_rocket):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

max_tpr_rf_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rf]
max_tpr_xgb_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_xgb]
max_tpr_rocket_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rocket]


multiples_45s = 10*['45']
tpr_df_rf_45s = pd.DataFrame({
    'time': multiples_45s,
    'model': rf_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rf_by_split
})
tpr_df_xgb_45s = pd.DataFrame({
    'time': multiples_45s,
    'model': rocket_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_xgb_by_split
})
tpr_df_rocket_45s = pd.DataFrame({
    'time': multiples_45s,
    'model': xgb_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rocket_by_split
})
tpr_df_all_45s = pd.concat([tpr_df_rf_45s, tpr_df_xgb_45s, tpr_df_rocket_45s], ignore_index=True)

# %%
# loading the results for random forest and xgboost
results1_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results1.csv")
results2_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results2.csv")
results3_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results3.csv")
results4_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results4.csv")
results5_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results5.csv")
results6_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results6.csv")
results7_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results7.csv")
results8_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results8.csv")
results9_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results9.csv")
results10_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/rf_results10.csv")


results1_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results1.csv")
results2_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results2.csv")
results3_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results3.csv")
results4_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results4.csv")
results5_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results5.csv")
results6_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results6.csv")
results7_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results7.csv")
results8_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results8.csv")
results9_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results9.csv")
results10_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_60s/xgb_results10.csv")

results1_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle1.csv")
results2_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle2.csv")
results3_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle3.csv")
results4_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle4.csv")
results5_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle5.csv")
results6_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle6.csv")
results7_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle7.csv")
results8_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle8.csv")
results9_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle9.csv")
results10_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_60s/rocketresults_vehicle10.csv")

# %%
results_list_rf = [results1_rf, results2_rf, results3_rf, results4_rf, results5_rf,
                results6_rf, results7_rf, results8_rf, results9_rf, results10_rf]
for idx, i in enumerate(results_list_rf):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1  # or use idx if you want 0-based

results_list_xgb = [results1_xgb, results2_xgb, results3_xgb, results4_xgb, results5_xgb,
                               results6_xgb, results7_xgb, results8_xgb, results9_xgb, results10_xgb]
for idx, i in enumerate(results_list_xgb):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

results_list_rocket = [results1_rocket, results2_rocket, results3_rocket, results4_rocket, results5_rocket,
                               results6_rocket, results7_rocket, results8_rocket, results9_rocket, results10_rocket]
for idx, i in enumerate(results_list_rocket):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

max_tpr_rf_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rf]
max_tpr_xgb_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_xgb]
max_tpr_rocket_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rocket]


multiples_60s = 10*['60']
tpr_df_rf_60s = pd.DataFrame({
    'time': multiples_60s,
    'model': rf_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rf_by_split
})
tpr_df_xgb_60s = pd.DataFrame({
    'time': multiples_60s,
    'model': rocket_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_xgb_by_split
})
tpr_df_rocket_60s = pd.DataFrame({
    'time': multiples_60s,
    'model': xgb_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rocket_by_split
})
tpr_df_all_60s = pd.concat([tpr_df_rf_60s, tpr_df_xgb_60s, tpr_df_rocket_60s], ignore_index=True)

# %%
# loading the results for random forest and xgboost
results1_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results1.csv")
results2_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results2.csv")
results3_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results3.csv")
results4_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results4.csv")
results5_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results5.csv")
results6_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results6.csv")
results7_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results7.csv")
results8_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results8.csv")
results9_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results9.csv")
results10_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/rf_results10.csv")


results1_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results1.csv")
results2_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results2.csv")
results3_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results3.csv")
results4_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results4.csv")
results5_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results5.csv")
results6_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results6.csv")
results7_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results7.csv")
results8_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results8.csv")
results9_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results9.csv")
results10_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_75s/xgb_results10.csv")

results1_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle1.csv")
results2_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle2.csv")
results3_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle3.csv")
results4_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle4.csv")
results5_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle5.csv")
results6_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle6.csv")
results7_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle7.csv")
results8_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle8.csv")
results9_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle9.csv")
results10_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_75s/rocketresults_vehicle10.csv")

# %%
results_list_rf = [results1_rf, results2_rf, results3_rf, results4_rf, results5_rf,
                results6_rf, results7_rf, results8_rf, results9_rf, results10_rf]
for idx, i in enumerate(results_list_rf):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1  # or use idx if you want 0-based

results_list_xgb = [results1_xgb, results2_xgb, results3_xgb, results4_xgb, results5_xgb,
                               results6_xgb, results7_xgb, results8_xgb, results9_xgb, results10_xgb]
for idx, i in enumerate(results_list_xgb):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

results_list_rocket = [results1_rocket, results2_rocket, results3_rocket, results4_rocket, results5_rocket,
                               results6_rocket, results7_rocket, results8_rocket, results9_rocket, results10_rocket]
for idx, i in enumerate(results_list_rocket):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

max_tpr_rf_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rf]
max_tpr_xgb_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_xgb]
max_tpr_rocket_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rocket]


multiples_75s = 10*['75']
tpr_df_rf_75s = pd.DataFrame({
    'time': multiples_75s,
    'model': rf_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rf_by_split
})
tpr_df_xgb_75s = pd.DataFrame({
    'time': multiples_75s,
    'model': rocket_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_xgb_by_split
})
tpr_df_rocket_75s = pd.DataFrame({
    'time': multiples_75s,
    'model': xgb_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rocket_by_split
})
tpr_df_all_75s = pd.concat([tpr_df_rf_75s, tpr_df_xgb_75s, tpr_df_rocket_75s], ignore_index=True)

# %%
# loading the results for random forest and xgboost
results1_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results1.csv")
results2_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results2.csv")
results3_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results3.csv")
results4_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results4.csv")
results5_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results5.csv")
results6_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results6.csv")
results7_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results7.csv")
results8_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results8.csv")
results9_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results9.csv")
results10_rf = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/rf_results10.csv")


results1_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results1.csv")
results2_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results2.csv")
results3_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results3.csv")
results4_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results4.csv")
results5_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results5.csv")
results6_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results6.csv")
results7_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results7.csv")
results8_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results8.csv")
results9_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results9.csv")
results10_xgb = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_veh_90s/xgb_results10.csv")

results1_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle1.csv")
results2_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle2.csv")
results3_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle3.csv")
results4_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle4.csv")
results5_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle5.csv")
results6_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle6.csv")
results7_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle7.csv")
results8_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle8.csv")
results9_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle9.csv")
results10_rocket = pd.read_csv("C:/Users/satavans/Downloads/RF_XGB_Results_Featimps/Results_XGB_RF_Veh/results_rocket_veh_90s/rocketresults_vehicle10.csv")

# %%
results_list_rf = [results1_rf, results2_rf, results3_rf, results4_rf, results5_rf,
                results6_rf, results7_rf, results8_rf, results9_rf, results10_rf]
for idx, i in enumerate(results_list_rf):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1  # or use idx if you want 0-based

results_list_xgb = [results1_xgb, results2_xgb, results3_xgb, results4_xgb, results5_xgb,
                               results6_xgb, results7_xgb, results8_xgb, results9_xgb, results10_xgb]
for idx, i in enumerate(results_list_xgb):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

results_list_rocket = [results1_rocket, results2_rocket, results3_rocket, results4_rocket, results5_rocket,
                               results6_rocket, results7_rocket, results8_rocket, results9_rocket, results10_rocket]
for idx, i in enumerate(results_list_rocket):
    prob = i['predicted_prob']
    # getting roc
    false_pos_rate, true_pos_rate, thresh = roc_curve(i['target'], prob)
    i['max_tpr_split'] = true_pos_rate[false_pos_rate == 0].max()
    i['split'] = idx + 1

max_tpr_rf_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rf]
max_tpr_xgb_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_xgb]
max_tpr_rocket_by_split = [df['max_tpr_split'].iloc[0] for df in results_list_rocket]


multiples_90s = 10*['90']
tpr_df_rf_90s = pd.DataFrame({
    'time': multiples_90s,
    'model': rf_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rf_by_split
})
tpr_df_xgb_90s = pd.DataFrame({
    'time': multiples_90s,
    'model': rocket_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_xgb_by_split
})
tpr_df_rocket_90s = pd.DataFrame({
    'time': multiples_90s,
    'model': xgb_multiples,
    'predictors': "Vehicle",
    'max_tpr': max_tpr_rocket_by_split
})
tpr_df_all_90s = pd.concat([tpr_df_rf_90s, tpr_df_xgb_90s, tpr_df_rocket_90s], ignore_index=True)

# %%
tpr_df_comb = pd.concat([tpr_df_all_15s, tpr_df_all_30s, tpr_df_all_45s, tpr_df_all_60s, tpr_df_all_75s, tpr_df_all_90s], ignore_index=True)

# %%
tpr_df_comb
# Out:
#     time          model predictors   max_tpr
# 0     15  Random Forest    Vehicle  0.183046
# 1     15  Random Forest    Vehicle  0.112399
# 2     15  Random Forest    Vehicle  0.125879
# 3     15  Random Forest    Vehicle  0.000000
# 4     15  Random Forest    Vehicle  0.114618
# ..   ...            ...        ...       ...
# 175   90        XGBoost    Vehicle  0.598272
# 176   90        XGBoost    Vehicle  0.517778
# 177   90        XGBoost    Vehicle  0.426501
# 178   90        XGBoost    Vehicle  0.531959
# 179   90        XGBoost    Vehicle  0.400871
#
# [180 rows x 4 columns]

# %%
# saving csv file
tpr_df_comb.to_csv('max_tpr_df_veh.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
